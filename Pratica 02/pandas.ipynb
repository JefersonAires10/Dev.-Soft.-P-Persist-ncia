# %%
import pandas as pd

# %%
df = pd.read_csv('veiculos.csv')
df
# Out:
#    Year    Make                                   Model  \
# 0  1997    Ford                                    E350
# 1  1999   Chevy              Venture "Extended Edition"
# 2  1999   Chevy  Venture "Extended Edition, Very Large"
# 3  1996    Jeep                          Grand Cherokee
# 4  2024  Toyota                                 Corolla
#
#                          Description     Price
# 0                      ac, abs, moon    3000.0
# 1                                NaN    4900.0
# 2                                NaN    5000.0
# 3  MUST SELL! air, moon roof, loaded    4799.0
# 4                                Red  100000.0

# %%
df2 = pd.read_csv('veiculos.tsv')
df2
# Out:
#                                                                             Year\tMake\tModel\tDescription\tPrice
# 1997\tFord\tE350\tac                                abs                                              moon\t3000.0
# 1999\tChevy\t"Venture ""Extended Edition"""\t\t... NaN                                                        NaN
# 1999\tChevy\t"Venture ""Extended Edition            Very Large"""\t\t5000.0                                   NaN
# 1996\tJeep\tGrand Cherokee\tMUST SELL! air          moon roof                                      loaded\t4799.0

# %%
df3 = pd.read_excel('veiculos.xlsx')
df3
# Out:
#    Year    Make                                   Model  \
# 0  1997    Ford                                    E350
# 1  1999   Chevy              Venture "Extended Edition"
# 2  1999   Chevy  Venture "Extended Edition, Very Large"
# 3  1996    Jeep                          Grand Cherokee
# 4  2024  Toyota                                 Corolla
#
#                          Description   Price
# 0                      ac, abs, moon    3000
# 1                                NaN    4900
# 2                                NaN    5000
# 3  MUST SELL! air, moon roof, loaded    4799
# 4                                Red  100000

# %%
dfs = pd.read_excel('Notas Disciplina de Engenharia de Software 2024.1.xlsx', sheet_name=None)
print(dfs.keys())
print(dfs['Consolidação das Notas'])
# Out:
# dict_keys(['Seminário', 'Apresent. Parcial', 'Apresent. Final', 'Ponto seminário', 'AP1', 'Consolidação das Notas'])
#     Matrícula                                       Nome  Nota AP1  Nota AP2  \
# 0      471151              ANDRESSA LIMA COLARES(Perfil)      3.50     10.00
# 1      496183         ANTONIA IANA OLIVEIRA LIMA(Perfil)      6.50      9.00
# 2      538555        ANTONIO DEIVID SANTOS COSTA(Perfil)      5.00      8.50
# 3      537634     BEATRIZ NASCIMENTO DE OLIVEIRA(Perfil)      8.00      9.50
# 4      507842        CARLOS CAUET FERREIRA COSTA(Perfil)      2.50      8.00
# 5      473007           CARLOS RYAN SANTOS SILVA(Perfil)      6.00      8.75
# 6      538863          CHRISTIAN ESTEVAM BARBOSA(Perfil)      5.00     10.00
# 7      536894            DANILO DOS SANTOS GOMES(Perfil)      8.00     10.00
# 8      469934            DAVI JOSE LIMA DE SOUSA(Perfil)      5.50      8.75
# 9      536587           ELYSSON ALVES DE LACERDA(Perfil)      9.00      9.75
# ...
